# %% [markdown]
# # 10 Reproducibility Workflow
# 示範最小可重現分析流程。

# %%
from pathlib import Path
import pandas as pd

# %%
path = Path('data/synthetic/line_list.csv')
df = pd.read_csv(path)
summary = {'n_rows': len(df), 'n_locations': df['location'].nunique(), 'n_deaths': int((df['outcome'] == 'dead').sum())}
summary
