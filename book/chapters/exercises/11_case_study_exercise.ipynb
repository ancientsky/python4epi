# %% [markdown]
# # 11 Case Study Exercise\n目標：完成地區病例率排序並提出資源優先順序。

# %%
import pandas as pd

# %%
line = pd.read_csv('data/synthetic/line_list.csv', parse_dates=['date_onset'])\n# TODO: 依 location 計算 cases\n# TODO: 建立 population 表\n# TODO: 計算 incidence_per_100k 並排序
