# %% [markdown]
# # 03 描述性統計與 2×2 表 — 練習
#
# 用松柏護理之家退伍軍人症 line list 練習建立 2×2 表、計算 RR 和卡方檢定。

# %%
# Google Colab setup -- 若在本機執行可跳過此 cell
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
from epi_learning.metrics import risk_ratio

df = pd.read_csv("data/synthetic/legionella_outbreak.csv")
df["infected"] = (df["clinical_severity"] != "not_ill").astype(int)

# %% [markdown]
# ## 題目 1：COPD × 感染的 2×2 表
#
# 1. 用 `pd.crosstab()` 建立 `comorbidity_copd × infected` 的 2×2 表
# 2. 從表中提取四格數值（a, b, c, d）
# 3. 計算 RR 和 95% CI
# 4. 做卡方檢定，印出 p-value
# 5. 解讀：COPD 是否為感染的危險因子？

# %%
# TODO: 建立 comorbidity_copd × infected 的 crosstab
# TODO: 提取 a, b, c, d
# TODO: 計算 RR
# TODO: 計算 95% CI（對數轉換法）
# TODO: 卡方檢定
# TODO: 印出結果並解讀

# %% [markdown]
# ## 題目 2：各共病的 RR 排名
#
# 1. 對以下 5 個共病因子，分別計算 RR 和 p-value：
#    - `comorbidity_chf`, `comorbidity_dm`, `comorbidity_cancer`, `comorbidity_copd`, `immunosuppressed`
# 2. 把結果整理成 DataFrame，按 RR 由大到小排序
# 3. 哪個共病的 RR 最高？哪些有統計顯著性？

# %%
# TODO: 用 for 迴圈計算 5 個共病的 RR 和 p-value
# TODO: 整理成 DataFrame 並排序

# %% [markdown]
# ## 題目 3（挑戰題）：性別差異分析
#
# 1. 建立 `sex × infected` 的 2×2 表
# 2. 計算 RR、95% CI、卡方 p-value
# 3. 再分別計算男性和女性的致死率（CFR = deaths / infected）
# 4. 思考：如果 RR 不顯著但 CFR 有差異，可能的解釋是什麼？

# %%
# TODO: sex × infected 的 2×2 表和 RR
# TODO: 分性別計算 CFR
# TODO: 解讀差異
