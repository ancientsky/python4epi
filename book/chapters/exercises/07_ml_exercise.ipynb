# %% [markdown]
# # 07 ML Exercise\n目標：完成最小分類 pipeline 並計算 AUC。

# %%
import pandas as pd\n# TODO: import sklearn components

# %%
df = pd.read_csv('data/synthetic/line_list.csv')\n# TODO: 建立 target, X, y\n# TODO: 建立 preprocess + model pipeline\n# TODO: 切分資料、訓練、計算 AUC
