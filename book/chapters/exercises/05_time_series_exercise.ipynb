# %% [markdown]
# # 05 Time Series Exercise\n目標：建立 rolling mean baseline 並計算 MAE。

# %%
import pandas as pd\n# TODO: from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('data/synthetic/line_list.csv', parse_dates=['date_onset'])\n# TODO: 建立每日序列 series\n# TODO: pred = ...\n# TODO: actual = ...\n# TODO: mean_absolute_error(actual, pred)
