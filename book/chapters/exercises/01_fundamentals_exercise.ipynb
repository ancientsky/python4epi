# %% [markdown]
# # 01 Python 基礎 — 練習
#
# 松柏護理之家的退伍軍人症群聚事件，你收到了以下初步數據。請用 Python 計算各項指標。

# %%
# Google Colab setup -- 若在本機執行可跳過此 cell
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
# === 題目 1：計算基本指標 ===
# 以下是 3 樓 B 翼的數據（侵襲率最高的翼區）
residents_3b = 47
infected_3b = 27
deaths_3b = 5
hospitalized_3b = 18

# TODO: 計算侵襲率 (attack_rate_3b)
# TODO: 計算致死率 (cfr_3b)
# TODO: 計算住院率 (hosp_rate_3b)
# TODO: 用 print + f-string 印出三個百分比

# %%
# === 題目 2：條件判斷 ===
# 如果 3B 翼的侵襲率 > 50%，印出「建議立即關閉該翼區淋浴設備」
# 否則印出「持續監測中」
# TODO: 寫出 if/else 條件判斷

# %%
# === 題目 3（挑戰題）：用字典 + 迴圈比較各翼區 ===
# 下面的字典包含六個翼區的資料。
# TODO: 用 for 迴圈計算每個翼區的侵襲率，並找出侵襲率最高的翼區。

wings = {
    "1A": {"residents": 44, "infected": 15},
    "1B": {"residents": 47, "infected": 10},
    "2A": {"residents": 44, "infected": 24},
    "2B": {"residents": 50, "infected": 25},
    "3A": {"residents": 48, "infected": 20},
    "3B": {"residents": 47, "infected": 27},
}

# TODO: 迴圈計算 + 找出最高侵襲率翼區

# %%
# === 題目 4：COVID-19 基本指標（變數與算術）===
# 某長照機構 COVID-19 疫情：住民 500 人、確診 180 人、死亡 12 人
total = 500
cases = 180
deaths = 12
# TODO: 計算 attack_rate（侵襲率 = 確診 / 住民）與 cfr（致死率 = 死亡 / 確診）
# TODO: 用 f-string 印出「侵襲率 = XX.X%、致死率 = XX.X%」

# %%
# === 題目 5：登革熱百分比與四捨五入（登革熱情境）===
# 某社區登革熱：通報 640 例，其中 58 例為重症（DHF）
reported = 640
severe = 58
# TODO: 計算重症比例（%），用 round() 取到小數 1 位
# TODO: 用 f-string 印出「重症比例 = X.X%」

# %%
# === 題目 6：結核病月報 list 與迴圈（結核情境）===
# 某縣市一年 12 個月的結核病通報數
monthly = [42, 38, 45, 50, 61, 55, 48, 40, 39, 44, 52, 47]
# TODO: 用內建函式或迴圈算：全年總數、月平均、最高的月份（1-12）
# TODO: 印出結果

# %%
# === 題目 7：麻疹疫苗接種率 dict（麻疹情境）===
# 各國小的 MMR 疫苗接種率（%）
coverage = {"忠孝國小": 97.2, "仁愛國小": 88.5, "信義國小": 95.0, "和平國小": 82.3}
# TODO: 用迴圈找出接種率最低的學校
# TODO: 計算有幾間學校低於群體免疫門檻 95%，並印出這些學校

# %%
# === 題目 8（挑戰題）：流感各區發生率（巢狀資料 + 條件判斷）===
# 各行政區的流感（cases, population）
regions = {"北區": (120, 80000), "南區": (60, 95000),
           "東區": (45, 30000), "西區": (30, 70000)}
# TODO: 用迴圈算每區每十萬人發生率 = cases / population * 100000
# TODO: 用 if/else 把每區標為「高風險（>=100/10萬）」或「一般」
# TODO: 印出各區發生率與分級
