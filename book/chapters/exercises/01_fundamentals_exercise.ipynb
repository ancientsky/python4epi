# %% [markdown]
# # 01 Python 基礎 — 練習
#
# 松柏護理之家的退伍軍人症群聚事件，你收到了以下初步數據。請用 Python 計算各項指標。

# %%
# Google Colab setup -- 若在本機執行可跳過此 cell
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
# === 題目 1：計算基本指標 ===
# 以下是 3 樓 B 翼的數據（侵襲率最高的翼區）
residents_3b = 47
infected_3b = 27
deaths_3b = 5
hospitalized_3b = 18

# TODO: 計算侵襲率 (attack_rate_3b)
# TODO: 計算致死率 (cfr_3b)
# TODO: 計算住院率 (hosp_rate_3b)
# TODO: 用 print + f-string 印出三個百分比

# %%
# === 題目 2：條件判斷 ===
# 如果 3B 翼的侵襲率 > 50%，印出「建議立即關閉該翼區淋浴設備」
# 否則印出「持續監測中」
# TODO: 寫出 if/else 條件判斷

# %%
# === 題目 3（挑戰題）：用字典 + 迴圈比較各翼區 ===
# 下面的字典包含六個翼區的資料。
# TODO: 用 for 迴圈計算每個翼區的侵襲率，並找出侵襲率最高的翼區。

wings = {
    "1A": {"residents": 44, "infected": 15},
    "1B": {"residents": 47, "infected": 10},
    "2A": {"residents": 44, "infected": 24},
    "2B": {"residents": 50, "infected": 25},
    "3A": {"residents": 48, "infected": 20},
    "3B": {"residents": 47, "infected": 27},
}

# TODO: 迴圈計算 + 找出最高侵襲率翼區
