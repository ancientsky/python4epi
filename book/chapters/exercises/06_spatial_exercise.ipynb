# %% [markdown]
# # 06 Spatial Exercise
# 目標：計算病例率並畫 choropleth。

# %%
import json
import pandas as pd
import plotly.express as px

# %%
pop = pd.read_csv('data/synthetic/location_population.csv')
cases = pd.read_csv('data/synthetic/line_list.csv').groupby('location').size().rename('cases').reset_index()
# TODO: merge 後計算 incidence_per_100k

# %%
# TODO: 讀取 data/synthetic/admin_areas.geojson
# TODO: 畫 choropleth（locations='location', featureidkey='properties.location'）
