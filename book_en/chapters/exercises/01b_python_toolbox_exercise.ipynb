# %% [markdown]
# # 01b The Python Developer's Toolbox — Exercises
#
# These exercises test your understanding of Ch01b: indentation, import, types, reading errors, try/except, and string operations.

# %%
# Google Colab setup -- skip this cell if running locally
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
# === Problem 1: import and statistics ===
# Use the statistics module to compute the mean and median length of stay for the following 8 hospitalized cases
hospital_days = [5, 3, 12, 7, 4, 9, 6, 8]

# TODO: import statistics (alias it as stats)
# TODO: use stats.mean() to compute the mean length of stay
# TODO: use stats.median() to compute the median
# TODO: print the result with an f-string

# %%
# === Problem 2: type conversion ===
# The following data was read from a CSV and is all text type
cases_str = "121"
population_str = "280"
deaths_str = "19"

# TODO: convert the three text variables to integers
# TODO: compute the attack_rate and the cfr (case fatality rate)
# TODO: print the percentages with an f-string (keep 2 decimal places)

# %%
# === Problem 3: reading errors ===
# Each of the 3 snippets below has a bug; identify the error type and fix it

# Bug 1: (hint: look at the variable name)
total_residents = 280
# print(total_resident)  # uncomment—what error do you see?
# TODO: fix it and print the correct result

# Bug 2: (hint: look at the type)
rate = "0.432"
# threshold = rate > 0.5  # uncomment—what error do you see?
# TODO: fix it and print the comparison result

# Bug 3: (hint: look at the key name)
patient = {"age": 72, "sex": "M", "floor": 3, "wing": "B"}
# print(patient["Wing"])  # uncomment—what error do you see?
# TODO: fix it and print the correct result

# %%
# === Problem 4: try/except ===
# The following list contains the infected counts for each wing (some are missing values in text form)
wing_data = ["15", "10", "N/A", "25", "missing", "27"]

# TODO: use a for loop + try/except to collect the values that can be converted to integers into a clean_data list
# TODO: print the success count, the skipped count, and the sum of clean_data

# %%
# === Problem 5: string cleaning + loops ===
# The following is exposure-history data collected from a questionnaire (inconsistent case, extra whitespace)
exposures_raw = [" Shower ", "shower", "HYDROTHERAPY", " hydrotherapy", "Shower", "unknown"]

# TODO: use a for loop to clean each string with .strip() + .lower()
# TODO: count how many times "shower" appears after cleaning
# TODO: count how many times "hydrotherapy" appears after cleaning
# TODO: print the results

# %%
# === Problem 6 (challenge): putting it all together ===
# Simulate a mini line list (a list of dictionaries) and compute the attack rate for each floor
patients = [
    {"id": "P001", "floor": "3", "infected": "1"},
    {"id": "P002", "floor": "2", "infected": "0"},
    {"id": "P003", "floor": "3", "infected": "1"},
    {"id": "P004", "floor": "1", "infected": "N/A"},
    {"id": "P005", "floor": "2", "infected": "1"},
    {"id": "P006", "floor": "3", "infected": "0"},
    {"id": "P007", "floor": "1", "infected": "1"},
    {"id": "P008", "floor": "2", "infected": "1"},
]

# TODO: use a for loop to iterate over each patient
# TODO: use try/except to handle the N/A in the infected column
# TODO: use a dictionary to tally (residents, infected) for each floor
# TODO: print the attack rate for each floor

# %%
# === Problem 7: statistics module (norovirus scenario) ===
# Incubation periods (in hours) for cases of norovirus at a banquet
onset_hours = [24, 30, 28, 36, 26, 40, 32, 29, 34, 27]
# TODO: import statistics
# TODO: compute the mean, median, and standard deviation, and print them with an f-string (each to 1 decimal place)

# %%
# === Problem 8: try/except and type conversion (dengue fever scenario) ===
# Daily dengue fever case counts imported from a form, with missing values and noise
raw = ["12", "8", "N/A", "15", "", "9", "twenty", "20"]
# TODO: use a loop + try/except to sum the values that can be converted to int, skipping and counting the ones that can't
# TODO: print "valid days, total cases, unparseable count"

# %%
# === Problem 9 (challenge): defining a function + error handling (COVID-19 scenario) ===
# TODO: define cfr(deaths, cases) that returns the case fatality rate; raise ValueError when cases <= 0
# TODO: use try/except to test cfr(12, 180) and cfr(5, 0), printing the result or error message for each
