# %% [markdown]
# # 01 Python Basics — Exercises
#
# For the Legionnaires' disease outbreak at Pine and Cypress Nursing Home, you've received the following preliminary data. Use Python to compute each of the metrics.

# %%
# Google Colab setup -- skip this cell if running locally
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
# === Question 1: Compute the basic metrics ===
# Below is the data for 3rd floor wing B (the wing with the highest attack rate)
residents_3b = 47
infected_3b = 27
deaths_3b = 5
hospitalized_3b = 18

# TODO: Compute the attack rate (attack_rate_3b)
# TODO: Compute the case fatality rate (cfr_3b)
# TODO: Compute the hospitalization rate (hosp_rate_3b)
# TODO: Use print + f-string to print all three percentages

# %%
# === Question 2: Conditionals ===
# If the attack rate of wing 3B is > 50%, print "Recommend immediately shutting off the shower facilities in this wing"
# Otherwise print "Continuing to monitor"
# TODO: Write the if/else conditional

# %%
# === Question 3 (challenge): compare the wings using a dict + loop ===
# The dictionary below holds the data for the six wings.
# TODO: Use a for loop to compute each wing's attack rate, and find the wing with the highest attack rate.

wings = {
    "1A": {"residents": 44, "infected": 15},
    "1B": {"residents": 47, "infected": 10},
    "2A": {"residents": 44, "infected": 24},
    "2B": {"residents": 50, "infected": 25},
    "3A": {"residents": 48, "infected": 20},
    "3B": {"residents": 47, "infected": 27},
}

# TODO: Loop to compute + find the wing with the highest attack rate

# %%
# === Question 4: COVID-19 basic metrics (variables and arithmetic) ===
# A long-term care facility's COVID-19 outbreak: 500 residents, 180 confirmed cases, 12 deaths
total = 500
cases = 180
deaths = 12
# TODO: Compute attack_rate (attack rate = confirmed cases / residents) and cfr (case fatality rate = deaths / confirmed cases)
# TODO: Use an f-string to print "Attack rate = XX.X%, CFR = XX.X%"

# %%
# === Question 5: dengue fever percentage and rounding (dengue scenario) ===
# A community dengue fever outbreak: 640 cases reported, of which 58 are severe (DHF)
reported = 640
severe = 58
# TODO: Compute the severe case proportion (%), rounded to 1 decimal place with round()
# TODO: Use an f-string to print "Severe case proportion = X.X%"

# %%
# === Question 6: TB monthly reports, list and loop (tuberculosis scenario) ===
# A county/city's monthly TB case notifications over one year
monthly = [42, 38, 45, 50, 61, 55, 48, 40, 39, 44, 52, 47]
# TODO: Use built-in functions or a loop to compute: the yearly total, the monthly average, and the peak month (1-12)
# TODO: Print the results

# %%
# === Question 7: measles vaccination coverage dict (measles scenario) ===
# MMR vaccination coverage (%) at each elementary school
coverage = {"忠孝國小": 97.2, "仁愛國小": 88.5, "信義國小": 95.0, "和平國小": 82.3}
# TODO: Use a loop to find the school with the lowest coverage
# TODO: Compute how many schools are below the herd immunity threshold of 95%, and print those schools

# %%
# === Question 8 (challenge): influenza incidence rate by district (nested data + conditionals) ===
# Influenza (cases, population) for each administrative district
regions = {"北區": (120, 80000), "南區": (60, 95000),
           "東區": (45, 30000), "西區": (30, 70000)}
# TODO: Use a loop to compute each district's incidence rate per 100,000 = cases / population * 100000
# TODO: Use if/else to label each district as "high risk (>=100/100k)" or "general"
# TODO: Print each district's incidence rate and risk level
