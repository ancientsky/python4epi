# %% [markdown]
# # 02 Data Wrangling + Visualization Exercise\n完成欄位檢查、週別統計，並畫出經典流行曲線。

# %%
# Google Colab setup -- 若在本機執行可跳過此 cell
import sys
import os
if 'google.colab' in sys.modules:
    # !git clone https://github.com/ancientsky/python4epi.git /content/python4epi 2>/dev/null || true
    os.chdir('/content/python4epi')
    # !pip install -q -e .

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport plotly.express as px

# %%
raw = pd.read_csv('data/synthetic/line_list.csv')\n# TODO: print raw.head() 與 raw.columns

# %%
# TODO: date_onset 轉日期\n# TODO: 建立 epi_week\n# TODO: groupby epi_week 計數，存成 weekly

# %%
# TODO: 用 matplotlib 畫 epidemic curve（bar chart）\n# x 軸：date_onset，y 軸：cases

# %%
# TODO: 用 seaborn 畫 location 的病例長條圖

# %%
# TODO: 用 plotly 畫互動折線圖（weekly）
